# %%
import re
from dotenv import load_dotenv
from langchain_community.utilities.jira import JiraAPIWrapper
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
import os
from langchain_community.document_loaders import ConfluenceLoader

# Initialize ConfluenceLoader
loader = ConfluenceLoader(
    url=os.getenv('CONFLUENCE_CLOUD_URL'),
    username=os.getenv('CONFLUENCE_CLOUD_USER'),
    api_key=os.getenv('CONFLUENCE_CLOUD_TOKEN'),
    cloud=True
)

def get_confluence_page_content(page_id):
    """
    Get the content of a Confluence page.
    
    :param page_id: ID of the Confluence page
    :return: Content of the Confluence page
    """
    page = loader.confluence.get_page_by_id(page_id, expand="body.storage")
    content = page["body"]["storage"]["value"]
    return content

def get_confluence_page_comments(page_id):
    """
    Get all comments of a specific Confluence page.
    
    :param page_id: ID of the Confluence page
    :return: List of comments with timestamps
    """
    comments = loader.confluence.get_page_comments(page_id, expand="body.view.value", depth="all")["results"]
    comment_list = []
    for comment in comments:
        body = comment["body"]["view"]["value"]
        created = comment.get("created", "No timestamp")
        comment_list.append({"body": body, "created": created})
    return comment_list

# Example usage
page_id = '3557066091'

# Get page content
page_content = get_confluence_page_content(page_id)
print("Page Content:", page_content)

# Get page comments
page_comments = get_confluence_page_comments(page_id)
print("Page Comments:", page_comments)
# Out:
# Page Content: <h2><ac:emoticon ac:name="blue-star" ac:emoji-shortname=":calendar_spiral:" ac:emoji-id="1f5d3" ac:emoji-fallback="\uD83D\uDDD3" />&nbsp;Date</h2><p><time datetime="2024-09-26" /></p><h2><ac:emoticon ac:name="blue-star" ac:emoji-shortname=":busts_in_silhouette:" ac:emoji-id="1f465" ac:emoji-fallback="\uD83D\uDC65" />&nbsp;Participants</h2><ul><li><p><ac:link><ri:user ri:account-id="60d83aad0717c60069a63fa1" /></ac:link></p></li><li><p><ac:link><ri:user ri:account-id="603d9146c668f4006af6065b" /></ac:link> </p></li><li><p><ac:link><ri:user ri:account-id="603d914f20122b00686adc47" /></ac:link> </p></li><li><p><ac:link><ri:user ri:account-id="712020:b1bd0746-e1c8-4f3d-9c96-8980264c416d" /></ac:link> </p></li><li><p><ac:link><ri:user ri:account-id="603d914dc58c72007121411f" /></ac:link> </p></li><li><p><ac:link><ri:user ri:account-id="5c7c8f00039b847f6a382ab7" /></ac:link>  </p></li><li><p><ac:link><ri:user ri:account-id="5f59cc1b0cef2d007dd12757" /></ac:link></p></li><li><p><ac:link><ri:user ri:account-id="62526214d2839e006baf03f5" /></ac:link> </p></li><li><p><ac:link><ri:user ri:account-id="5ab36c1145a2562a4c64f63d" /></ac:link></p></li><li><p><ac:link><ri:user ri:account-id="712020:13586966-e256-4a85-8154-5e8900ed1fe3" /></ac:link> </p></li><li><p><ac:link><ri:user ri:account-id="712020:733d131d-d06e-4fb8-aa92-d9b507c0ddff" /></ac:link> </p></li><li><p><ac:link><ri:user ri:account-id="712020:251b4744-a064-4108-bf93-2df5ac7be53d" ri:local-id="ad7b859e-50f5-4de2-abd5-f62fd64835c2" /></ac:link> </p></li><li><p><ac:link><ri:user ri:account-id="712020:140ac018-ccca-4e8a-81ff-63745eb376d5" ri:local-id="29a1fee7-218b-499e-939d-2a2e2b2ff645" /></ac:link> </p></li><li><p><ac:link><ri:user ri:account-id="5e5c5aac5a495e0c91a9a0b4" /></ac:link> (optional)</p></li><li><p><ac:link><ri:user ri:account-id="712020:733d131d-d06e-4fb8-aa92-d9b507c0ddff" ri:local-id="8c6747d3-f55b-43bf-b0dc-e5a06d363b09" /></ac:link> (optional)</p></li><li><p><ac:link><ri:user ri:account-id="5f0bbe8707efc40028034d3f" /></ac:link> (optional)</p></li><li><p><ac:link><ri:user ri:account-id="557058:7009ab2d-3d88-49b5-8201-0d2f18e55a2d" /></ac:link> (optional)</p></li><li><p><ac:link><ri:user ri:account-id="557058:0248781a-6961-4038-bdf5-6323a4feb84a" ri:local-id="78b61566-9894-4be7-bd9d-c4d0dbfd8265" /></ac:link> (for sharing purposes)</p></li></ul><h2><ac:emoticon ac:name="blue-star" ac:emoji-shortname=":goal:" ac:emoji-id="1f945" ac:emoji-fallback="\uD83E\uDD45" />&nbsp;Goals</h2><p>High-level result sharing and reporting on the status of the Foundation Model TF for report generation. </p><h2><ac:emoticon ac:name="blue-star" ac:emoji-shortname=":speaking_head:" ac:emoji-id="1f5e3" ac:emoji-fallback="\uD83D\uDDE3" />&nbsp;Discussion topic</h2><table data-table-width="1434" data-layout="default" ac:local-id="83bf42fe-d524-4dbc-a0b2-13b46d2566ce"><colgroup><col style="width: 290.0px;" /><col style="width: 255.0px;" /><col style="width: 889.0px;" /></colgroup><tbody><tr><th data-highlight-colour="#deebff"><p><strong>Item</strong></p></th><th data-highlight-colour="#deebff"><p><strong>Presenter</strong></p></th><th data-highlight-colour="#deebff"><p><strong>Notes</strong></p></th></tr><tr><td colspan="3"><p><strong>Announcements </strong></p><ul><li><p /></li></ul></td></tr><tr><td><p>Sync on Direction </p><p><em>by ~10:10</em></p></td><td><p><ac:link><ri:user ri:account-id="60d83aad0717c60069a63fa1" ri:local-id="017e0ca4-e89d-4781-8e6f-995489ddb42d" /></ac:link> </p></td><td><p><strong>More Detailed Timeline </strong></p><ul><li><p><em>Test set (and little bit of train set) annotation based on CXR-Findings v1.2 </em></p><ul><li><p><em>Timeline: Now &ndash; </em><time datetime="2024-07-26" /><em>  </em><ac:structured-macro ac:name="status" ac:schema-version="1" ac:macro-id="08e0fe7f-a32e-4365-b732-e229a2c798f3"><ac:parameter ac:name="title">Done</ac:parameter><ac:parameter ac:name="colour">Blue</ac:parameter></ac:structured-macro> (finish by <time datetime ...
# <ac:task>
# <ac:task-id>2073</ac:task-id>
# <ac:task-uuid>2073</ac:task-uuid>
# <ac:task-status>incomplete</ac:task-status>
# <ac:task-body><span class="placeholder-inline-tasks"><ac:structured-macro ac:name="status" ac:schema-version="1" ac:macro-id="7c201e02-af94-4b27-9760-d2cff442a8c3"><ac:parameter ac:name="title">on track</ac:parameter><ac:parameter ac:name="colour">Green</ac:parameter></ac:structured-macro>Use training annotations for finetuning (annotation will be finished by end of September)</span></ac:task-body>
# </ac:task>
# <ac:task>
# <ac:task-id>2074</ac:task-id>
# <ac:task-uuid>2074</ac:task-uuid>
# <ac:task-status>incomplete</ac:task-status>
# <ac:task-body><span class="placeholder-inline-tasks"><ac:structured-macro ac:name="status" ac:schema-version="1" ac:macro-id="9ed3a2c2-608f-4734-bea1-4a5c02af8d92"><ac:parameter ac:name="title">on track</ac:parameter><ac:parameter ac:name="colour">Green</ac:parameter></ac:structured-macro>Test annotation review finished</span></ac:task-body>
# </ac:task>
# <ac:task>
# <ac:task-id>2075</ac:task-id>
# <ac:task-uuid>2075</ac:task-uuid>
# <ac:task-status>incomplete</ac:task-status>
# <ac:task-body><span class="placeholder-inline-tasks"><ac:structured-macro ac:name="status" ac:schema-version="1" ac:macro-id="ca6e6417-db8d-49d9-b26e-d8e76c076e1f"><ac:parameter ac:name="title">on track</ac:parameter><ac:parameter ac:name="colour">Green</ac:parameter></ac:structured-macro> (57x3) &rarr; report : strategy</span></ac:task-body>
# </ac:task>
# </ac:task-list><p><strong>By </strong><time datetime="2024-10-11" /> </p><ac:task-list>
# <ac:task>
# <ac:task-id>2076</ac:task-id>
# <ac:task-uuid>2076</ac:task-uuid>
# <ac:task-status>incomplete</ac:task-status>
# <ac:task-body><span class="placeholder-inline-tasks"><ac:structured-macro ac:name="status" ac:schema-version="1" ac:macro-id="bbc67e93-c84e-425e-99a0-b0ea9ff039cd"><ac:parameter ac:name="title">on track</ac:parameter><ac:parameter ac:name="colour">Green</ac:parameter></ac:structured-macro> Seeing performance metrics on 57 x 3</span></ac:task-body>
# </ac:task>
# <ac:task>
# <ac:task-id>2077</ac:task-id>
# <ac:task-uuid>2077</ac:task-uuid>
# <ac:task-status>incomplete</ac:task-status>
# <ac:task-body><span class="placeholder-inline-tasks"><ac:structured-macro ac:name="status" ac:schema-version="1" ac:macro-id="a64632a3-6704-40e5-b8ac-b1c288f33388"><ac:parameter ac:name="title">todo</ac:parameter></ac:structured-macro> (57x3) &rarr; report : implementation</span></ac:task-body>
# </ac:task>
# <ac:task>
# <ac:task-id>2078</ac:task-id>
# <ac:task-uuid>2078</ac:task-uuid>
# <ac:task-status>incomplete</ac:task-status>
# <ac:task-body><span class="placeholder-inline-tasks"><ac:structured-macro ac:name="status" ac:schema-version="1" ac:macro-id="50630d60-906c-4d45-b023-428575919332"><ac:parameter ac:name="title">need help</ac:parameter><ac:parameter ac:name="colour">Yellow</ac:parameter></ac:structured-macro> report evaluation: metrics, benchmark, comp to SOTA</span></ac:task-body>
# </ac:task>
# </ac:task-list><p><strong>By </strong><time datetime="2024-11-01" /> </p><ac:task-list>
# <ac:task>
# <ac:task-id>2079</ac:task-id>
# <ac:task-uuid>2079</ac:task-uuid>
# <ac:task-status>incomplete</ac:task-status>
# <ac:task-body><span class="placeholder-inline-tasks">Full report generated</span></ac:task-body>
# </ac:task>
# </ac:task-list></td></tr><tr><td><p>57 x 3 Performance</p><p><em>~ by 10:45</em></p></td><td><p><ac:link><ri:user ri:account-id="5f59cc1b0cef2d007dd12757" ri:local-id="b6edfee0-26cf-484f-8286-0bf8e2815201" /></ac:link> <ac:link><ri:user ri:account-id="62526214d2839e006baf03f5" ri:local-id="7c956eea-8336-4c99-98f3-3387fe3d5f91" /></ac:link> <ac:link><ri:user ri:account-id="603d914f20122b00686adc47" ri:local-id="18a0ec3f-7754-414c-8f84-5e5047c488ad" /></ac:link> </p></td><td><p><strong>Linear Layer Training</strong></p><p>Initial performance for section A, B and D is available: <ac:link ac:card-appearance="inline"><ri:page ri:content-title="2024-09-25 Linear-Layer Training for ABD Sections" ri:version-at-save="2" /><ac:link-body>2024-09-25 Linear-Layer Training for ABD Sections</ac:link-body></ac:link> </p><ul><li><p>Summary:</p><ul><li><p>Abnormality detection performance is quite good (&gt; 0.9 AUC)</p></li><li><p>Location prediction performance is moderate (0.8 ~ 0.9 AUC)</p></li><li><p>Severity prediction performance is bad (~0.5 accuracy) - most of them are 3-way classification</p></li></ul></li><li><p>Limitation / Next steps</p><ul><li><p>Current evaluation strategy is imperfect. Should be cleaned up.</p></li><li><p>Task of <code>location_severity</code> should be refined.</p></li><li><p>Training on human annotated data is necessary.</p></li></ul></li></ul><p><strong>Discussion</strong></p><ul><li><p>wrt to clean up of evaluation:  <ac:link><ri:user ri:account-id="603d914f20122b00686adc47" ri:local-id="c1e31089-3797-4347-b91d-81b984bdda2c" /></ac:link> &amp; <ac:link><ri:user ri:account-id="5f59cc1b0cef2d007dd12757" ri:local-id="e297c253-3a12-4809-a699-b73fdfafef25" /></ac:link> sync so double work is avoided.</p></li><li><p>Reporting only severe cases when reporting, more thinking needed per finding. </p></li></ul><hr /><p><strong>Instruction Tuning</strong></p><p>Initial experiment trained on all sections but evaluated only on A, B, D : <ac:link ac:card-appearance="inline"><ri:page ri:content-title="2024-09-19 LlavaNext initial experiment" ri:version-at-save="3" /><ac:link-body>2024-09-19 LlavaNext initial experiment</ac:link-body></ac:link> </p><ul><li><p>Summary:</p><ul><li><p>Good on medical devices but poor on Image quality and rare findings. Largely coming from lack of GT annotations for image quality. New GT training annotations should help.</p></li></ul></li><li><p>Next steps:</p><ul><li><p>Expert model (training only on section A) showed better trade off in sensitivity specificity so will try training expert model for each section. </p></li><li><p>Also use new GT training annotations to train model</p></li><li><p>Compare Linear Layer model with our expert instruction tuned models. We expect there wouldn&rsquo;t be obvious advantage in Instruction tuning for binary prediction and since we don&rsquo;t have control of sensitivity / specificity trade off due to not having probability output, we will explore focusing only on positive findings attribute prediction with instruction tuning.</p></li></ul></li></ul><p><strong>Discussion</strong></p><ul><li><p>Computational budget for RSNA demo?</p><ul><li><p>Unknown &rarr; will follow up after we know.  </p></li></ul></li><li><p>Regarding the release of human annotations: how to do train/tune/test split, is this blocking the release?</p><ul><li><p>econn1 &rarr; emergent-connect-1.0.0 (reprocessed) &rarr; there are 200 cases missing out of the 5K annotated cases in the emergent-connect-1.0.0.</p><ul><li><p>Can&rsquo;t we just add the 200 cases from econn1?</p></li><li><p>Add &amp; release ASAP, fix after release if it needs fixing </p></li></ul></li></ul></li><li><p>Low number of positives (severe=True) in test set:  how to deal with it under discussion.</p><ul><li><p>Research Question:  How to accurately measure model performance given not enough + imbalanced data?</p></li></ul></li></ul></td></tr><tr><td><p>Test set release</p><p><em>~ by 11:10</em></p></td><td><p><ac:lin ...
# <ac:task>
# <ac:task-id>2018</ac:task-id>
# <ac:task-uuid>2018</ac:task-uuid>
# <ac:task-status>incomplete</ac:task-status>
#
# </ac:task>
# </ac:task-list><h2><ac:emoticon ac:name="blue-star" ac:emoji-shortname=":arrow_heading_up:" ac:emoji-id="2934" ac:emoji-fallback="⤴" />&nbsp;Decisions</h2><p><ac:placeholder>Type /decision to record the decisions you make in this meeting:</ac:placeholder></p><ac:adf-extension><ac:adf-node type="decision-list"><ac:adf-attribute key="local-id">42e2cd57-9e90-4dd7-8644-42d5233b3f2e</ac:adf-attribute><ac:adf-node type="decision-item"><ac:adf-attribute key="local-id">58744669-a4f5-4322-a32a-6dfa87efe636</ac:adf-attribute><ac:adf-attribute key="state">DECIDED</ac:adf-attribute></ac:adf-node></ac:adf-node></ac:adf-extension><p />
# Page Comments: []

# %%
def get_all_child_pages(page_id, max_depth):
    """
    Recursively get child pages under a specific Confluence page up to a certain depth.
    
    :param page_id: ID of the parent Confluence page
    :param max_depth: Maximum depth to recurse
    :return: List of child pages with their content
    """
    def _get_child_pages(page_id, current_depth):
        if current_depth >= max_depth:
            return []
        child_pages = []
        direct_children = loader.confluence.get_page_child_by_type(
            page_id=page_id,
            type='page',
            start=None,
            limit=None,
            expand='body.storage'
        )
        for child in direct_children:
            child_id = child['id']
            child_title = child['title']
            child_content = child['body']['storage']['value']
            child_pages.append({
                'id': child_id,
                'title': child_title,
                'content': child_content
            })
            # Recursively get child pages of the current child
            child_pages.extend(_get_child_pages(child_id, current_depth + 1))
        return child_pages
    return _get_child_pages(page_id, 0)

# Example usage
page_id = '3006138328'  # Parent page ID
max_depth = 2  # Maximum depth

# Retrieve child pages up to the specified depth
limited_child_pages = get_all_child_pages(page_id, max_depth)

# Display the retrieved pages
for page in limited_child_pages:
    print(f"Page ID: {page['id']}, Title: {page['title']}")
# Out:
# Page ID: 3006563417, Title: Work Rules (ENG)
# Page ID: 3006432351, Title: Organization & Job (ENG)
# Page ID: 3006629295, Title: Work & Leave (ENG)
# Page ID: 3008200706, Title: Leave of Absence/Return to Work/Termination (ENG)
# Page ID: 3402072375, Title: Job classification table
# Page ID: 3008069650, Title: Salary/Compensation (ENG)
# Page ID: 3007676493, Title: Evaluation (ENG)
# Page ID: 3219196761, Title: Level (ENG)
# Page ID: 3110207795, Title: OKR (Objectives & Key Results) (ENG)
# Page ID: 3071312765, Title: [Seoul] Business trip
# Page ID: 3008102421, Title: Others (ENG)
# Page ID: 3078357142, Title: [Global] Work & Leave
# Page ID: 3021411267, Title: [Global] [Leave] Annual Leave
# Page ID: 3021411287, Title: [Global] [Leave] Sick Leave
# Page ID: 3021411373, Title: [Global] Termination Process
# Page ID: 3021411342, Title: [Global] Probationary Period
# Page ID: 3021411227, Title: [Global] HR Policy
# Page ID: 3125870662, Title: [Global] Business Trip Guide
# Page ID: 3021409229, Title: [Lunit USA] Business Expense & Trip Policies (Lunit USA Only)
# Page ID: 3007905809, Title: Expenses (ENG)
# Page ID: 3056697878, Title: Accounting 101 (ENG)
# Page ID: 3055978376, Title: Payment / Financial Monthly Closing
# Page ID: 3056730417, Title: Corporate Card Guidelines (Seoul Office Only)
# Page ID: 3056698059, Title: How to Use SAP Concur
# Page ID: 3056730656, Title: Requesting for Corporate Seal / Corporate Document
# Page ID: 3056730744, Title: [ENG] F&A Dept. FAQㅤ
# Page ID: 3110044739, Title: [Global] Expenses (ENG)
# Page ID: 3110208530, Title: [Global] Expense Reimbursement Process
# Page ID: 3006988583, Title: Recruitment (ENG)
# Page ID: 3089761060, Title: Hiring Process Overview
# Page ID: 3090022968, Title: Hiring Request
# Page ID: 3089925614, Title: Interview Etiquette
# Page ID: 3051618948, Title: Referral Program
# Page ID: 3021412371, Title: Part-time Job Recruitment Guide
# Page ID: 3056632366, Title: Internal Communication (ENG)
# Page ID: 3089629617, Title: All hands meeting(ENG)
# Page ID: 3089793582, Title: Communication Channel (ENG)
# Page ID: 3010396404, Title: Distress Resolution Support
# Page ID: 3103031997, Title: Interpretation Request Guide
# Page ID: 3052011973, Title: Information Security (ENG)
# Page ID: 3021472451, Title: Information Security Guide (ENG)
# Page ID: 3056566713, Title: Procedures related to Information Security (ENG)
# Page ID: 3056272806, Title: IT Operation (ENG)
# Page ID: 3148613510, Title: Information Security Policy(ENG)
# Page ID: 3008200725, Title: Benefits & Perks (ENG)
# Page ID: 3031434033, Title: Benefits
# Page ID: 3031467092, Title: Company/Department Activities
# Page ID: 3089629533, Title: Learning & Development (ENG)
# Page ID: 3090251777, Title: Luniversity (ENG)
# Page ID: 3293742432, Title: Education & Academic Conferences (ENG)
# Page ID: 2586477015, Title: Lectures
# Page ID: 3413049989, Title: Glossary for Lunitians (ENG)
# Page ID: 3292659972, Title: Leadership Principles (ENG)
# Page ID: 2598536725, Title: Situational 1:1 Questions
# Page ID: 3008397317, Title: Support Guide (ENG)
# Page ID: 3071312429, Title: Office guide
# Page ID: 3071148808, Title: Software/Equipment/Vehicle
# Page ID: 3071148843, Title: Post/Business card
# Page ID: 3093692536, Title: Tool
# Page ID: 3093529376, Title: Design Template (ENG)
# Page ID: 3056632380, Title: Legal & Compliance (ENG)
# Page ID: 3105259770, Title: Legal & Compliance Request
# Page ID: 3251667523, Title: Legal & Compliance Request (New)
# Page ID: 3008233490, Title: Culture (ENG)
# Page ID: 3292692679, Title: Lunit Culture Code
# Page ID: 3089465924, Title: Lunitian (Lunit+Martian)(ENG)
# Page ID: 3497069012, Title: Intellectual Property (Patent, Trademark, Design, etc)
